# %%
import jittor as jt

# %%
help(jt.cudnn.ops.cudnn_rnn)
# Out:
# Help on built-in function cudnn_rnn in module gen_ops_cudnn_conv3d_backward_w_cudnn_conv3d_backw___hash78c3ee.ops:
#
# cudnn_rnn(...)
#     Declaration:
#     vector_to_tuple<VarHolder*> cudnn_rnn(VarHolder* x, VarHolder* hx, VarHolder* cx, VarHolder* w,  string mode,  int input_size,  int hidden_size,  int num_layers,  int proj_size,  double dropout,  bool batch_first,  bool bias,  bool bidirectional)
#
#     Declaration:
#     vector_to_tuple<VarHolder*> cudnn_rnn_(VarHolder* x, VarHolder* hx, VarHolder* w,  string mode,  int input_size,  int hidden_size,  int num_layers,  int proj_size,  double dropout,  bool batch_first,  bool bias,  bool bidirectional)

# %%
help(jt.cudnn_lstm)
